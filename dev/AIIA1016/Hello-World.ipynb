# %%
import pandas as pd
data = {
    "records": [
        {
            "event_id": "EVT-001",
            "timestamp": "2026-03-24T08:12:34Z",
            "source_ip": "192.168.1.45",
            "severity": "LOW",
            "message": "Successful user login via SSO."
        },
        {
            "event_id": "EVT-002",
            "timestamp": "2026-03-24T08:45:11Z",
            "source_ip": "203.0.113.77",
            "severity": "HIGH",
            "message": "Brute-force SSH login attempt detected from external IP."
        },
        {
            "event_id": "EVT-003",
            "timestamp": "2026-03-24T09:03:58Z",
            "source_ip": "192.168.1.88",
            "severity": "CRITICAL",
            "message": "Outbound connection to known C2 server detected."
        },
        {
            "event_id": "EVT-004",
            "timestamp": "2026-03-24T10:17:22Z",
            "source_ip": "192.168.2.15",
            "severity": "HIGH",
            "message": "User accessed SQL Server with SA-level privileges after hours."
        },
        {
            "event_id": "EVT-005",
            "timestamp": "2026-03-24T11:30:05Z",
            "source_ip": "192.168.1.55",
            "severity": "CRITICAL",
            "message": "Large outbound file transfer (2.3 GB) to personal cloud storage blocked."
        }
    ]
}


df = pd.DataFrame(data)
print(df)
# Out:
#                                              records
# 0  {'event_id': 'EVT-001', 'timestamp': '2026-03-...
# 1  {'event_id': 'EVT-002', 'timestamp': '2026-03-...
# 2  {'event_id': 'EVT-003', 'timestamp': '2026-03-...
# 3  {'event_id': 'EVT-004', 'timestamp': '2026-03-...
# 4  {'event_id': 'EVT-005', 'timestamp': '2026-03-...
